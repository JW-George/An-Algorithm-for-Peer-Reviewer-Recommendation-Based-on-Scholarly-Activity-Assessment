# %%
# 균등할당 이전
# Out:
#                                        submitter_title      date  \
# 0                           Diversifying Top-K Results  20200101
# 1                           Diversifying Top-K Results  20200101
# 2                           Diversifying Top-K Results  20200101
# 3                           Diversifying Top-K Results  20200101
# 4                           Diversifying Top-K Results  20200101
# ..                                                 ...       ...
# 595  Keyword Search over Relational Databases: A Me...  20200410
# 596  Keyword Search over Relational Databases: A Me...  20200410
# 597  Keyword Search over Relational Databases: A Me...  20200410
# 598  Keyword Search over Relational Databases: A Me...  20200410
# 599  Keyword Search over Relational Databases: A Me...  20200410
#
#         submitter_name     reviewer_name  reviewer_orcid       sim  count
# 0               Lu Qin  Foteini Katsarou             866  0.076316      0
# ...

# %%
#균등할당 이후
# Out:
# ('Diversifying Top-K Results', 20200101, 'Lu Qin', 'Hoang Vu Nguyen', 907, 0.11554054054054053, 1)
# ('Diversifying Top-K Results', 20200101, 'Lu Qin', 'Yuhong Li', 1360, 0.11554054054054053, 1)
# ('Diversifying Top-K Results', 20200101, 'Lu Qin', 'Jing Wang', 960, 0.07832594463128473, 1)
# ('A Generic Framework for Efficient and Effective Subsequence Retrieval', 20200102, 'Haohan Zhu', 'Yudian Zheng', 1358, 0.11554054054054053, 1)
# ('A Generic Framework for Efficient and Effective Subsequence Retrieval', 20200102, 'Haohan Zhu', 'Arian Bar', 730, 0.07832594463128473, 1)
# ('A Generic Framework for Efficient and Effective Subsequence Retrieval', 20200102, 'Haohan Zhu', 'Chih-Ya Shen', 776, 0.07832594463128473, 1)
# ('A Comparison of Flexible Schemas for Software as a Service', 20200103, 'Stefan Aulbach', 'Jing Wang', 960, 0.12180451127819547, 2)
# ('A Comparison of Flexible Schemas for Software as a Service', 20200103, 'Stefan Aulbach', 'Mingzhu Wei', 1082, 0.11861504307305325, 1)
# ...
